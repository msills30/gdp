# %%
# Import dependencies

from bs4 import BeautifulSoup
import requests
import pandas as pd
import ssl

# %%
#kind of had to "brute force" the path


url = "https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)"
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
# Set the URL to visit to a variable
ssl._create_default_https_context = ssl._create_unverified_context

scraper = pd.read_html(url)
for idx, table in enumerate(scraper):
    print("****************************************************************")
    print(idx)
    print(table)
# Out:
# ****************************************************************
# 0
#                                                    0
# 0  Largest economies in the world by GDP (nominal...
# ****************************************************************
# 1
#                                                    0  \
# 0  .mw-parser-output .legend{page-break-inside:av...
#
#                                                    1  \
# 0  $750 billion – $1 trillion $500–750 billion $2...
#
#                                                    2
# 0  $50–100 billion $25–50 billion $5–25 billion <...
# ****************************************************************
# 2
#     Country/Territory UN region IMF[1][13]            World Bank[14]  \
#     Country/Territory UN region   Forecast       Year       Estimate
# 0               World         —  104476432       2023      100562011
# 1       United States  Americas   26949643       2023       25462700
# ...

# %%
results_df=pd.DataFrame(scraper[2])
# Export the election_Data into a csv
# results_df.to_csv("outputs/election.csv", index_label="False")
(results_df)
# Out:
#     Country/Territory UN region IMF[1][13]            World Bank[14]  \
#     Country/Territory UN region   Forecast       Year       Estimate
# 0               World         —  104476432       2023      100562011
# 1       United States  Americas   26949643       2023       25462700
# 2               China      Asia   17700899  [n 1]2023       17963171
# 3             Germany    Europe    4429838       2023        4072192
# 4               Japan      Asia    4230862       2023        4231141
# ..                ...       ...        ...        ...            ...
# 209             Palau   Oceania        267       2023              —
# 210          Kiribati   Oceania        246       2023            223
# 211             Nauru   Oceania        150       2023            151
# 212        Montserrat  Americas          —          —              —
# 213            Tuvalu   Oceania         63       2023             60
#
#                United Nations[15]
# ...

# %%
results_df.columns = results_df.str.strip()
results_df

# %%
results_df.to_csv("C:/Users/m8rqu/Documents/Data BootCamp/Econ/Data/gdp.csv", index_label="False")
